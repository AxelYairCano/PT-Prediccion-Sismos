# %% [markdown]
# ## Maquetación de la Red Neuronal

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# --- 1. CONFIGURACIÓN DE PARÁMETROS ESPECÍFICOS ---
# Configuración de la ANN para predicción de sismos en Chile.
N_ENTRADAS = 7       # Variaciones de valor-b, Magnitud máxima 7 días, Probabilidad M>6.0, etc.
N_OCULTAS = 15       # Neuronas Capa Oculta (Teorema de Kolmogorov)
N_SALIDA = 1         # Magnitud máxima esperada en los próximos 5 días.

# --- 2. DATOS SIMULADOS ---
# X_simulado: 1000 ejemplos de entrenamiento con 7 características de entrada.
# Cada fila representa un día/ventana de tiempo con sus 7 parámetros sísmicos.
X_simulado = np.random.rand(1000, N_ENTRADAS) * 10 

# y_train_simulado: 1000 valores de salida (Magnitud máxima observada en los siguientes 5 días).
# Valores de magnitud simulados entre 4.0 y 8.0.
y_simulado = np.random.uniform(low=4.0, high=8.0, size=(1000, N_SALIDA))

# %% [markdown]
# ## Definimos el Modelo (Arquitectura)

# %%
# Inicialización del modelo secuencial
model = Sequential()

# --- Capa Oculta ---
# Neuronas: 15
# Función de Activación: Sigmoide
# input_shape: Define la forma de la entrada (7 variables).
model.add(Dense(
    units=N_OCULTAS,
    activation='sigmoid', 
    input_shape=(N_ENTRADAS,)
))

# --- Capa de Salida ---
# Neuronas: 1 
# Función de Activación: 'linear' para regresión.
model.add(Dense(
    units=N_SALIDA,
    activation='linear' 
))

# 3. Muestra el Modelo
print("--- Resumen del Modelo de la Red Neuronal ---")
model.summary()
# Out:
# c:\Users\Axel Cano\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# --- Resumen del Modelo de la Red Neuronal ---
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 15)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 136 (544.00 B)
#  Trainable params: 136 (544.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Entrenamiento

# %%
# 1. Configuración para el entrenamiento.
# Loss: MSE (Error Cuadrático Medio).
model.compile(
    optimizer='adam',       # adam optimizador
    loss='mse',             # MSE (Error Cuadrático Medio)
    metrics=['mae']         # MAE (Error Absoluto Medio)
)

# 2. ENTRENAMIENTO
print("\n--- Iniciando Entrenamiento Simulado ---")

history = model.fit(
    X_simulado,
    y_simulado,
    epochs=50,              # Número de iteraciones sobre el dataset
    batch_size=32,          # Tamaño de muestras
    verbose=1
)

print("\n--- Entrenamiento Finalizado ---")
# Out:
# --- Iniciando Entrenamiento Simulado ---
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 44.0428 - mae: 6.5282
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.5302 - mae: 5.8426
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.3467 - mae: 5.0931
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.5305 - mae: 4.3749
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8993 - mae: 3.8111
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.9179 - mae: 3.4008
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7455 - mae: 3.0684
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9922 - mae: 2.7721
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5391 - mae: 2.4938
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2498 - mae: 2.2238
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1362 - mae: 1.9613
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2431 - mae: 1.7438
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5581 - mae: 1.5767
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0346 - mae: 1.4459
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6252 - mae: 1.3394
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3029 - mae: 1.2551
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0568 - mae: 1.1878
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8645 - mae: 1.1358
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7180 - mae: 1.0929
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6057 - mae: 1.0626
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5166 - mae: 1.0364
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4532 - mae: 1.0171
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4072 - mae: 1.0043
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3698 - mae: 0.9936
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3452 - mae: 0.9866
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3257 - mae: 0.9807
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3128 - mae: 0.9767
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3033 - mae: 0.9731
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2968 - mae: 0.9710
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2917 - mae: 0.9693
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2884 - mae: 0.9678
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2858 - mae: 0.9668
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2841 - mae: 0.9660
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2829 - mae: 0.9655
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2823 - mae: 0.9650
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2821 - mae: 0.9648
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2811 - mae: 0.9644
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2808 - mae: 0.9642
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2804 - mae: 0.9640
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2801 - mae: 0.9639
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2799 - mae: 0.9638
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2795 - mae: 0.9637
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2796 - mae: 0.9639
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2792 - mae: 0.9636
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2790 - mae: 0.9635
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2785 - mae: 0.9633
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2784 - mae: 0.9633
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2782 - mae: 0.9634
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2781 - mae: 0.9633
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2777 - mae: 0.9632
#
# --- Entrenamiento Finalizado ---

# %% [markdown]
# ## Simulación de Predicción

# %%
# Simular un nuevo conjunto de datos de prueba con 7 entradas
X_test_simulado = np.random.rand(7, N_ENTRADAS) * 10 

# Realizar la predicción
predictions = model.predict(X_test_simulado)

print("\n--- Predicciones Simuladas de Magnitud Máxima (en 5 días) ---")
for i, pred in enumerate(predictions):
    # La salida es la magnitud máxima esperada
    print(f"Entrada {i+1}: Magnitud predicha = {pred[0]:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
#
# --- Predicciones Simuladas de Magnitud Máxima (en 5 días) ---
# Entrada 1: Magnitud predicha = 6.06
# Entrada 2: Magnitud predicha = 6.04
# Entrada 3: Magnitud predicha = 6.04
# Entrada 4: Magnitud predicha = 6.10
# Entrada 5: Magnitud predicha = 6.03
# Entrada 6: Magnitud predicha = 6.04
# Entrada 7: Magnitud predicha = 6.07
